# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('weather2.csv');

# %%
a=pd.DataFrame(df)
print(df.shape)
a.head(1)
# Out:
# (366, 24)
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
#
#    RISK_MM  RainTomorrow
# 0      3.6           Yes
#
# [1 rows x 24 columns]

# %%
x=df['MinTemp']
sns.distplot(x)
# Out:
# C:\Users\shreya\Anaconda3-5\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(x,kde=False,rug=True)
# Out:
# C:\Users\shreya\Anaconda3-5\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
y=df['MaxTemp']
sns.distplot(y,hist=False,rug=True)

# %%
sns.kdeplot(x, shade=True)

# %%
a=df['Sunshine']
sns.kdeplot(a, label='original')
sns.kdeplot(a, bw=0.2, label='bw=0.2')
sns.kdeplot(a, bw=2, label='bw=2')
plt.legend()
# Out:
# C:\Users\shreya\Anaconda3-5\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\shreya\Anaconda3-5\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
a = pd.DataFrame(df, columns=['Humidity3pm', 'Humidity9am'])
a.head(1)
# Out:
#    Humidity3pm  Humidity9am
# 0           29           68

# %%
a.plot(kind='scatter', x = 'Humidity3pm', y = 'Humidity9am')

# %%
sns.jointplot(x='Humidity3pm', y='Humidity9am', data=a)
# Out:
# C:\Users\shreya\Anaconda3-5\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\shreya\Anaconda3-5\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
with sns.axes_style('white'):
    sns.jointplot(x = df['MinTemp'], y =df['MaxTemp'], kind = 'hex', color = 'k', data=a )
# Out:
# C:\Users\shreya\Anaconda3-5\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\shreya\Anaconda3-5\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x=df['MinTemp'], y=df['MaxTemp'],  kind='kde')

# %%
a = pd.DataFrame(df, columns=['Humidity3pm', 'Humidity9am','MinTemp','MaxTemp'])
sns.pairplot(a)

# %%
a=pd.DataFrame(df)

a.describe(include='all')
# Out:
#              Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count         366       366  366.000000  366.000000  366.000000   366.000000
# unique        366         1         NaN         NaN         NaN          NaN
# top     1/28/2008  Canberra         NaN         NaN         NaN          NaN
# freq            1       366         NaN         NaN         NaN          NaN
# mean          NaN       NaN    7.265574   20.550273    1.428415     4.521858
# std           NaN       NaN    6.025800    6.690516    4.225800     2.669383
# min           NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%           NaN       NaN    2.300000   15.025000    0.000000     2.200000
# 50%           NaN       NaN    7.450000   19.650000    0.000000     4.200000
# 75%           NaN       NaN   12.500000   25.500000    0.200000     6.400000
# max           NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
# ...

# %%
sns.stripplot(x ='Rainfall', y='Sunshine', data=a,jitter=False)

# %%
sns.stripplot(x='Rainfall', y='Sunshine', data=a, jitter=True)

# %%
sns.swarmplot(x='Humidity9am', y='Pressure9am', data=a)

# %%
sns.boxplot(x='Cloud9am', y='Pressure9am', data=a)

# %%
print(a[a.WindDir3pm=='E'])
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 21   11/22/2007  Canberra     16.4     19.4       0.4          9.2       0.0
# 25   11/26/2007  Canberra     15.6     26.9       0.0          6.8       8.9
# 26   11/27/2007  Canberra     13.3     22.2       0.2          6.6       2.3
# 34    12/5/2007  Canberra     14.5     21.8       0.0          8.4       9.8
# 40   12/11/2007  Canberra     11.8     18.5       0.6          4.8       2.3
# 41   12/12/2007  Canberra     11.7     21.5       0.0          4.2       7.3
# 42   12/13/2007  Canberra      9.6     20.3       0.0          5.0       3.6
# 47   12/18/2007  Canberra      7.5     20.9       0.0          6.6       8.7
# 65     1/5/2008  Canberra     12.1     27.5       0.0          7.4      11.7
# ...

# %%
a.Rainfall[a.WindDir3pm=='E'].value_counts()
# Out:
# 0.0    14
# 0.4     1
# 0.2     1
# 0.6     1
# Name: Rainfall, dtype: int64

# %%
sns.boxplot(x='RainToday', y='Humidity3pm', data=a, hue='WindDir3pm', dodge=True)

# %%
sns.barplot(x='RainToday', y='Rainfall', data=a)
